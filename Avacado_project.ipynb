# %% [markdown]
# # AVACADO

# %% [markdown]
# The avocado (Persea americana) is a tree originating in the Americas which is likely native to the highland regions of south-central Mexico to Guatemala. It is classified as a member of the flowering plant family Lauraceae.The fruit of the plant, also called an avocado (or avocado pear or alligator pear), is botanically a large berry containing a single large seed.Avocado trees are partially self-pollinating, and are often propagated through grafting to maintain predictable fruit quality and quantity.
#
# Avocados are cultivated in tropical and Mediterranean climates of many countries, with Mexico as the leading producer of avocados in 2019, supplying 32% of the world total.
#
# The fruit of domestic varieties has a buttery flesh when ripe. Depending on the variety, avocados have green, brown, purplish, or black skin when ripe, and may be pear-shaped, egg-shaped, or spherical. Commercially, the fruits are picked while immature, and ripened after harvesting.

# %% [markdown]
# # Data Description

# %% [markdown]
# This data was downloaded from the Hass Avocado Board website in May of 2018 & compiled into a single CSV.
#
# The table below represents weekly 2018 retail scan data for National retail volume (units) and price. Retail scan data comes directly from retailers’ cash registers based on actual retail sales of Hass avocados.
#
# Starting in 2013, the table below reflects an expanded, multi-outlet retail data set. Multi-outlet reporting includes an aggregation of the following channels: grocery, mass, club, drug, dollar and military. The Average Price (of avocados) in the table reflects a per unit (per avocado) cost, even when multiple units (avocados) are sold in bags.
#
# The Product Lookup codes (PLU’s) in the table are only for Hass avocados. Other varieties of avocados (e.g. greenskins) are not included in this table.

# %% [markdown]
# # Loading The DataSet

# %%
import pandas as pd
import numpy as np
df=pd.read_csv("Avacado.csv")
df
# Out:
#        Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0             0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1             1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2             2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3             3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4             4.0  29-11-2015          1.28      51039.60   941.48   43838.39
# ...           ...         ...           ...           ...      ...        ...
# 16463         NaN         NaN           NaN           NaN      NaN        NaN
# 16464         NaN         NaN           NaN           NaN      NaN        NaN
# 16465         NaN         NaN           NaN           NaN      NaN        NaN
# 16466         NaN         NaN           NaN           NaN      NaN        NaN
# 16467         NaN         NaN           NaN           NaN      NaN        NaN
#
#          4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0       48.16     8696.87     8603.62       93.25          0.0  conventional
# 1       58.33     9505.56     9408.07       97.49          0.0  conventional
# 2      130.50     8145.35     8042.21      103.14          0.0  conventional
# 3       72.58     5811.16     5677.40      133.76          0.0  conventional
# 4       75.78     6183.95     5986.26      197.69          0.0  conventional
# ...       ...         ...         ...         ...          ...           ...
# 16463     NaN         NaN         NaN         NaN          NaN           NaN
# 16464     NaN         NaN         NaN         NaN          NaN           NaN
# 16465     NaN         NaN         NaN         NaN          NaN           NaN
# 16466     NaN         NaN         NaN         NaN          NaN           NaN
# 16467     NaN         NaN         NaN         NaN          NaN           NaN
#
#          year  region
# 0      2015.0  Albany
# 1      2015.0  Albany
# 2      2015.0  Albany
# 3      2015.0  Albany
# 4      2015.0  Albany
# ...       ...     ...
# 16463     NaN     NaN
# 16464     NaN     NaN
# 16465     NaN     NaN
# 16466     NaN     NaN
# 16467     NaN     NaN
#
# [16468 rows x 14 columns]

# %%
df.head()
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0         0.0  27-12-2015          1.33      64236.62  1036.74   54454.85
# 1         1.0  20-12-2015          1.35      54876.98   674.28   44638.81
# 2         2.0  13-12-2015          0.93     118220.22   794.70  109149.67
# 3         3.0  06-12-2015          1.08      78992.15  1132.00   71976.41
# 4         4.0  29-11-2015          1.28      51039.60   941.48   43838.39
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# 1   58.33     9505.56     9408.07       97.49          0.0  conventional
# 2  130.50     8145.35     8042.21      103.14          0.0  conventional
# 3   72.58     5811.16     5677.40      133.76          0.0  conventional
# 4   75.78     6183.95     5986.26      197.69          0.0  conventional
#
#      year  region
# 0  2015.0  Albany
# 1  2015.0  Albany
# 2  2015.0  Albany
# 3  2015.0  Albany
# 4  2015.0  Albany

# %%
df.tail()
# Out:
#        Unnamed: 0 Date  AveragePrice  Total Volume  4046  4225  4770  \
# 16463         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16464         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16465         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16466         NaN  NaN           NaN           NaN   NaN   NaN   NaN
# 16467         NaN  NaN           NaN           NaN   NaN   NaN   NaN
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags type  year region
# 16463         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16464         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16465         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16466         NaN         NaN         NaN          NaN  NaN   NaN    NaN
# 16467         NaN         NaN         NaN          NaN  NaN   NaN    NaN

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Date', 'AveragePrice', 'Total Volume', '4046', '4225',
#        '4770', 'Total Bags', 'Small Bags', 'Large Bags', 'XLarge Bags', 'type',
#        'year', 'region'],
#       dtype='object')

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %% [markdown]
# # Checking For Null And Empty Values in DataSet

# %%
df.isnull().sum()
# Out:
# Date            14951
# AveragePrice    14951
# Total Volume    14951
# 4046            14951
# 4225            14951
# 4770            14951
# Total Bags      14951
# Small Bags      14951
# Large Bags      14951
# XLarge Bags     14951
# type            14951
# year            14951
# region          14951
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

sns.heatmap(df.isnull())
plt.title("Null Values")
plt.show()

# %% [markdown]
# # Checking and Transforming the Data types of the Columns To Same DataTypes for Better Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16468 entries, 0 to 16467
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1517 non-null   object
#  1   AveragePrice  1517 non-null   float64
#  2   Total Volume  1517 non-null   float64
#  3   4046          1517 non-null   float64
#  4   4225          1517 non-null   float64
#  5   4770          1517 non-null   float64
#  6   Total Bags    1517 non-null   float64
#  7   Small Bags    1517 non-null   float64
#  8   Large Bags    1517 non-null   float64
#  9   XLarge Bags   1517 non-null   float64
#  10  type          1517 non-null   object
#  11  year          1517 non-null   float64
#  12  region        1517 non-null   object
# dtypes: float64(10), object(3)
# memory usage: 1.6+ MB

# %%
df.describe(include=['O'])
# Out:
#               Date          type      region
# count         1517          1517        1517
# unique         104             1          51
# top     12-04-2015  conventional  California
# freq            34          1517          76

# %%
from sklearn.preprocessing import LabelEncoder
le =LabelEncoder()

list1=['type','region']
for val in list1:
  df[val]=le.fit_transform(df[val].astype(str))

# %%
df
# Out:
#              Date  AveragePrice  Total Volume     4046       4225    4770  \
# 0      27-12-2015          1.33      64236.62  1036.74   54454.85   48.16
# 1      20-12-2015          1.35      54876.98   674.28   44638.81   58.33
# 2      13-12-2015          0.93     118220.22   794.70  109149.67  130.50
# 3      06-12-2015          1.08      78992.15  1132.00   71976.41   72.58
# 4      29-11-2015          1.28      51039.60   941.48   43838.39   75.78
# ...           ...           ...           ...      ...        ...     ...
# 16463         NaN           NaN           NaN      NaN        NaN     NaN
# 16464         NaN           NaN           NaN      NaN        NaN     NaN
# 16465         NaN           NaN           NaN      NaN        NaN     NaN
# 16466         NaN           NaN           NaN      NaN        NaN     NaN
# 16467         NaN           NaN           NaN      NaN        NaN     NaN
#
#        Total Bags  Small Bags  Large Bags  XLarge Bags  type    year  region
# 0         8696.87     8603.62       93.25          0.0     0  2015.0       0
# 1         9505.56     9408.07       97.49          0.0     0  2015.0       0
# 2         8145.35     8042.21      103.14          0.0     0  2015.0       0
# 3         5811.16     5677.40      133.76          0.0     0  2015.0       0
# 4         6183.95     5986.26      197.69          0.0     0  2015.0       0
# ...           ...         ...         ...          ...   ...     ...     ...
# 16463         NaN         NaN         NaN          NaN     1     NaN      51
# 16464         NaN         NaN         NaN          NaN     1     NaN      51
# 16465         NaN         NaN         NaN          NaN     1     NaN      51
# 16466         NaN         NaN         NaN          NaN     1     NaN      51
# 16467         NaN         NaN         NaN          NaN     1     NaN      51
#
# [16468 rows x 13 columns]

# %%
df.plot.scatter(x='AveragePrice',y='region')
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='region'>

# %%
plt.figure(figsize=(5,5))
sns.countplot(df.type)
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='type', ylabel='count'>

# %%
df.type.value_counts()
# Out:
# 1    14951
# 0     1517
# Name: type, dtype: int64

# %%
sns.barplot(data=df, x="AveragePrice", y="region")
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='region'>

# %%
df.region.value_counts()
# Out:
# 51    14951
# 6        76
# 0        67
# 3        65
# 2        65
# 4        62
# 1        54
# 31       52
# 5        51
# 44       49
# 9        47
# 26       44
# 19       41
# 12       40
# 42       39
# 38       38
# 49       36
# 47       34
# 22       34
# 7        31
# 34       30
# 17       29
# 28       29
# 50       27
# 48       25
# 25       25
# 41       24
# 11       24
# 8        23
# 13       23
# 32       22
# 36       21
# 29       21
# 15       19
# 46       19
# 14       18
# 24       18
# 23       17
# 10       17
# 37       17
# 45       16
# 35       16
# 18       16
# 39       15
# 16       13
# 30       13
# 33       12
# 27       12
# 20       10
# 43        9
# 40        9
# 21        3
# Name: region, dtype: int64

# %%
sns.lineplot(x='AveragePrice',y='Total Volume',data=df)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Total Volume'>

# %%
sns.barplot(data=df, x="AveragePrice", y="4046")
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='4046'>

# %%
df.plot.hexbin(x='AveragePrice', y='4225', gridsize=15)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='4225'>

# %%
df.plot.scatter(x='AveragePrice',y='4770')
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='4770'>

# %%
sns.barplot(data=df, x="AveragePrice", y="Total Bags")
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Total Bags'>

# %%
sns.lineplot(x='AveragePrice',y='Small Bags',data=df)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Small Bags'>

# %%
sns.lineplot(x='year',y='type',data=df)
# Out:
# <AxesSubplot:xlabel='year', ylabel='type'>

# %%
df.groupby('year')['type'].value_counts()
# Out:
# year    type
# 2015.0  0       1270
# 2016.0  0        247
# Name: type, dtype: int64

# %%
df.plot.hexbin(x='AveragePrice', y='Large Bags', gridsize=15)
# Out:
# <AxesSubplot:xlabel='AveragePrice', ylabel='Large Bags'>

# %%
sns.countplot(df['year'])
# Out:
# C:\Users\Admin\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='year', ylabel='count'>

# %%
df.year.value_counts()
# Out:
# 2015.0    1270
# 2016.0     247
# Name: year, dtype: int64

# %%
sns.displot(df['region'])

# %%
sns.displot(df['type'])

# %%
df.hist(figsize=(15,30),edgecolor='red',layout=(9,4),bins=15,legend=True)
plt.show()

# %% [markdown]
# # Coorelation

# %%
df.corr()
# Out:
#               AveragePrice  Total Volume      4046      4225      4770  \
# AveragePrice      1.000000     -0.140470 -0.190096 -0.092084 -0.100567
# Total Volume     -0.140470      1.000000  0.985568  0.987154  0.934347
# 4046             -0.190096      0.985568  1.000000  0.951952  0.898570
# 4225             -0.092084      0.987154  0.951952  1.000000  0.927757
# 4770             -0.100567      0.934347  0.898570  0.927757  1.000000
# Total Bags       -0.111597      0.967689  0.930395  0.951779  0.926405
# Small Bags       -0.097682      0.960642  0.922278  0.943988  0.923607
# Large Bags       -0.177480      0.910226  0.884229  0.900496  0.840523
# XLarge Bags      -0.048284      0.521717  0.474063  0.504718  0.646053
# type                   NaN           NaN       NaN       NaN       NaN
# year              0.178683     -0.004189 -0.040439 -0.007254  0.029222
# region           -0.229408      0.236579  0.269481  0.215733  0.138092
#
#               Total Bags  Small Bags  Large Bags  XLarge Bags      type  \
# AveragePrice   -0.111597   -0.097682   -0.177480    -0.048284       NaN
# Total Volume    0.967689    0.960642    0.910226     0.521717       NaN
# 4046            0.930395    0.922278    0.884229     0.474063       NaN
# 4225            0.951779    0.943988    0.900496     0.504718       NaN
# 4770            0.926405    0.923607    0.840523     0.646053       NaN
# Total Bags      1.000000    0.997341    0.911336     0.601856       NaN
# Small Bags      0.997341    1.000000    0.879131     0.611300       NaN
# Large Bags      0.911336    0.879131    1.000000     0.447779       NaN
# XLarge Bags     0.601856    0.611300    0.447779     1.000000       NaN
# type                 NaN         NaN         NaN          NaN  1.000000
# year            0.090108    0.106382   -0.018678     0.218342       NaN
# region          0.190001    0.168650    0.297452    -0.046144  0.869561
#
#                   year    region
# AveragePrice  0.178683 -0.229408
# Total Volume -0.004189  0.236579
# 4046         -0.040439  0.269481
# 4225         -0.007254  0.215733
# 4770          0.029222  0.138092
# Total Bags    0.090108  0.190001
# Small Bags    0.106382  0.168650
# Large Bags   -0.018678  0.297452
# XLarge Bags   0.218342 -0.046144
# type               NaN  0.869561
# year          1.000000 -0.470472
# region       -0.470472  1.000000

# %%
df.corr()['AveragePrice'].sort_values()
# Out:
# region         -0.229408
# 4046           -0.190096
# Large Bags     -0.177480
# Total Volume   -0.140470
# Total Bags     -0.111597
# 4770           -0.100567
# Small Bags     -0.097682
# 4225           -0.092084
# XLarge Bags    -0.048284
# year            0.178683
# AveragePrice    1.000000
# type                 NaN
# Name: AveragePrice, dtype: float64

# %%
df.corr()['region'].sort_values()
# Out:
# year           -0.470472
# AveragePrice   -0.229408
# XLarge Bags    -0.046144
# 4770            0.138092
# Small Bags      0.168650
# Total Bags      0.190001
# 4225            0.215733
# Total Volume    0.236579
# 4046            0.269481
# Large Bags      0.297452
# type            0.869561
# region          1.000000
# Name: region, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns
plt.figure(figsize=(15,7))
sns.heatmap(df.corr(), annot=True, linewidths=0.5,linecolor="black", fmt='.2f')
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Descriptive Statistics

# %%
df.describe()
# Out:
#        AveragePrice  Total Volume          4046          4225          4770  \
# count   1517.000000  1.517000e+03  1.517000e+03  1.517000e+03  1.517000e+03
# mean       1.074990  1.601879e+06  6.464387e+05  6.114375e+05  5.040550e+04
# std        0.188891  4.433143e+06  1.947614e+06  1.672906e+06  1.377812e+05
# min        0.490000  3.875074e+04  4.677200e+02  1.783770e+03  0.000000e+00
# 25%        0.980000  1.474700e+05  2.040034e+04  4.147606e+04  9.112500e+02
# 50%        1.080000  4.027919e+05  8.175117e+04  1.186649e+05  7.688170e+03
# 75%        1.190000  9.819751e+05  3.775785e+05  4.851503e+05  2.916730e+04
# max        1.680000  4.465546e+07  1.893304e+07  1.895648e+07  1.381516e+06
#
#          Total Bags    Small Bags    Large Bags    XLarge Bags          type  \
# count  1.517000e+03  1.517000e+03  1.517000e+03    1517.000000  16468.000000
# mean   2.935974e+05  2.487736e+05  4.264205e+04    2181.771074      0.907882
# std    7.579765e+05  6.474765e+05  1.182157e+05    7455.712144      0.289201
# min    3.311770e+03  3.311770e+03  0.000000e+00       0.000000      0.000000
# 25%    3.620689e+04  2.972722e+04  5.407400e+02       0.000000      1.000000
# 50%    7.397906e+04  6.237569e+04  5.044350e+03       0.000000      1.000000
# 75%    1.576097e+05  1.461994e+05  2.926767e+04     401.480000      1.000000
# max    6.736304e+06  5.893642e+06  1.121076e+06  108072.790000      1.000000
#
#               year        region
# count  1517.000000  16468.000000
# mean   2015.162821     48.254554
# std       0.369324      9.912157
# min    2015.000000      0.000000
# 25%    2015.000000     51.000000
# 50%    2015.000000     51.000000
# 75%    2015.000000     51.000000
# max    2016.000000     51.000000

# %%
plt.figure(figsize=(15,7))
sns.heatmap(round(df.describe()[1:].transpose(),2), annot=True, linewidths=0.5,linecolor="black", fmt='f')
# Out:
# <AxesSubplot:>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16468 entries, 0 to 16467
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Date          1517 non-null   object
#  1   AveragePrice  1517 non-null   float64
#  2   Total Volume  1517 non-null   float64
#  3   4046          1517 non-null   float64
#  4   4225          1517 non-null   float64
#  5   4770          1517 non-null   float64
#  6   Total Bags    1517 non-null   float64
#  7   Small Bags    1517 non-null   float64
#  8   Large Bags    1517 non-null   float64
#  9   XLarge Bags   1517 non-null   float64
#  10  type          16468 non-null  int32
#  11  year          1517 non-null   float64
#  12  region        16468 non-null  int32
# dtypes: float64(10), int32(2), object(1)
# memory usage: 1.5+ MB

# %% [markdown]
# # Checking Data To Remove Skewness

# %%
df.iloc[:,:-1].skew()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_10916/2362345884.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.iloc[:,:-1].skew()
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# type           -2.821090
# year            1.828332
# dtype: float64

# %%
df.iloc[:,:-1].skew()
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_10916/2362345884.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df.iloc[:,:-1].skew()
# AveragePrice   -0.109444
# Total Volume    6.200138
# 4046            6.051830
# 4225            6.394926
# 4770            5.405164
# Total Bags      5.366378
# Small Bags      5.355185
# Large Bags      5.144495
# XLarge Bags     5.775077
# type           -2.821090
# year            1.828332
# dtype: float64

# %%
import warnings
warnings.filterwarnings('ignore')
df.plot(kind='box',subplots=True, layout=(3,5), figsize=[20,8])
# Out:
# AveragePrice       AxesSubplot(0.125,0.657941;0.133621x0.222059)
# Total Volume    AxesSubplot(0.285345,0.657941;0.133621x0.222059)
# 4046             AxesSubplot(0.44569,0.657941;0.133621x0.222059)
# 4225            AxesSubplot(0.606034,0.657941;0.133621x0.222059)
# 4770            AxesSubplot(0.766379,0.657941;0.133621x0.222059)
# Total Bags         AxesSubplot(0.125,0.391471;0.133621x0.222059)
# Small Bags      AxesSubplot(0.285345,0.391471;0.133621x0.222059)
# Large Bags       AxesSubplot(0.44569,0.391471;0.133621x0.222059)
# XLarge Bags     AxesSubplot(0.606034,0.391471;0.133621x0.222059)
# type            AxesSubplot(0.766379,0.391471;0.133621x0.222059)
# year                  AxesSubplot(0.125,0.125;0.133621x0.222059)
# region             AxesSubplot(0.285345,0.125;0.133621x0.222059)
# dtype: object

# %% [markdown]
# # IQR Proximity Rule

# %%
#Z - Score Technique
from scipy.stats import zscore
import numpy as np
z=np.abs(zscore(df))
z.shape

# %%
threshold=3
print(np.where(z>3))

# %%
len(np.where(z>3)[0])

# %%
df.drop([ 1716,  2699,  5462,  5475,  5476,  5477,  5478,  5479,  5480,
        5481,  5482,  5483,  5484,  5485,  5486,  5487,  5488,  5489,
        5490,  5491,  5492,  5493,  5494,  5495,  5496,  5497,  5506,
        5506,  7412,  8319,  8322,  8344,  8344,  8345,  8345,  8346,
        8346,  8347,  8347,  8348,  8348,  8349,  8349,  8350,  8351,
        8352,  8352,  8353,  8353,  8354,  8354,  8355,  8356,  8357,
        8358,  8359,  8360,  8361,  8362,  8363,  8364,  8365,  8365,
        8366,  8366,  8366,  8367,  8367,  8368,  8369,  8370,  8371,
        9090,  9090,  9091,  9091,  9092,  9092,  9093,  9093,  9094,
        9094,  9095,  9096,  9096,  9097,  9097,  9097,  9097,  9098,
        9098,  9099,  9099,  9100,  9101,  9212,  9894, 10381, 11024,
       11320, 11321, 11322, 11325, 11326, 11332, 11333, 11336, 11338,
       11340, 11342, 11347, 11348, 11349, 11350, 11354, 11387, 11388,
       11594, 11595, 11596, 11597, 11614, 11662, 12132, 14124, 14125,
       14404, 15261, 15262, 15473, 16055, 16720, 17428],axis=0)
